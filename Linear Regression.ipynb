# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv(r"C:\Users\tonmo\Desktop\ML and DL\Machine Learning\Datasets\Salary_dataset.csv")

# %%
dataset.head(5)
# Out:
#    YearsExperience  Salary
# 0              1.2   39344
# 1              1.4   46206
# 2              1.6   37732
# 3              2.1   43526
# 4              2.3   39892

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.figure(figsize = (5,5))
sns.scatterplot(x = "YearsExperience",y = "Salary", data=dataset)
plt.show()

# %%
x = dataset[["YearsExperience"]]

# %%
y = dataset[["Salary"]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9024461774180498

# %%
lr.predict([[6.1]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[81865.47494996]])

# %%
y_prd = lr.predict(x)

# %%
plt.figure(figsize = (5,5))
sns.scatterplot(x = "YearsExperience",y = "Salary", data=dataset)
plt.plot(dataset["YearsExperience"],y_prd)
plt.show()
