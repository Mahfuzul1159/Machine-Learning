# %%
7
# Out:
# 7

# %%
import pandas as pd
import numpy as np
import requests
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import cycle

# %%
# Load dataset
data = pd.read_csv("Merged.csv")

# View sample data
print(data.head(20))
# Out:
#                                               comment       tag
# 0   আলহামদুলিল্লাহ সোনার বাংলার সোনার ছেলেরা দেশকে...  Positive
# 1                                            মাশাল্লা  Positive
# 2                                           এগিয়ে যাও  Positive
# 3                                             চমৎকার।  Positive
# 4   দেশের শিল্প পতিদের উচিত দেশিও প্রযুক্তি গুলোকে...   Neutral
# 5                                      আলহামদুলিল্লাহ  Positive
# 6   সোনার ছেলেরাও পারে।এদের পাশে শিল্পপতিরা দাড়ালে...  Positive
# 7   সব ঠিক আছে।   কিন্তু ফোল চার্জ হতে কত সময় লাগব...  Positive
# 8                                      আলহামদুলিল্লাহ  Positive
# 9   প্রয়জন আবিষ্কারের জনক। 'পালকি' তে সোলার রিলেডে...  Positive
# 10  দাম মধ্যবিত্তদের নাগালে রাখার অনুরোধ রইলো পালি...  Positive
# 11  আমি না শুধু মন চাইলে আপনারা ও কিনতে পারেন একলা...   Neutral
# 12  দেশের এসব তরুণ উদ্যোক্তাদের জন্য রইলো অনেক অনে...  Positive
# 13  ভাই তাড়াতাড়ি বানান আমাদের দরকার অনেক অনেক অন...  Positive
# 14  ৩ লক্ষ টাকার মধ্যে রাখতে হবে না হলে সুফল পাবে ...  Positive
# 15  বাংলাদেশে ইলেকট্রিক গাড়ির বড় একটি বাজার অলরে...  Positive
# 16      কত সুন্দর কথা "শুধু ভাত খেয়ে বেচে থাকতে পারি"  Positive
# 17    ভাই গাড়ির নাম টা এবং লোগো টা,  সুন্দর করা উচিত  Positive
# 18                                         মাশাআল্লাহ  Positive
# 19  ভাই চায়না অনেক বিদ্যুৎ চালিত গাড়ি আছে আপনার ...  Negative

# %%
# Check for missing values
print(data.isnull().sum())

# Drop missing values
data = data.dropna()
# Out:
# comment    0
# tag        5
# dtype: int64

# %%
# Correct common label typos
label_corrections = {
    "Neutural": "Neutral",
    "Meutral": "Neutral",
    "N EUTRAL": "Neutral",
    "NEUTRANEG": "Neutral",
    "Negetive": "Negative",
    "NEGNEG": "Negative",
    "Negativee": "Negative",
    "NEG": "Negative"
}

data['tag'] = data['tag'].replace(label_corrections)

# Remove the 'Neutral' class
data = data[data['tag'] != 'Neutral']

# %%
# Identify unique labels
print("Unique labels in dataset:", data['tag'].unique())

# Assume the first label is the positive class
positive_class_label = data['tag'].unique()[0]
positive_class = data[data['tag'] == positive_class_label]

# Reduce the count of the positive class
if len(positive_class) >= 8780:
    rows_to_remove = positive_class.sample(n=8780, random_state=42)
    data = data.drop(rows_to_remove.index)
else:
    print(f"Less than 10,000 positive rows available (found {len(positive_class)}).")
# Out:
# Unique labels in dataset: ['Positive' 'Negative']

# %%
# Load Bangla stopwords
stopwords_url = "https://raw.githubusercontent.com/stopwords-iso/stopwords-bn/master/stopwords-bn.txt"
response = requests.get(stopwords_url)

if response.status_code == 200:
    stop_words_bangla = set(response.text.splitlines())
    
    # Remove stopwords
    data['comment'] = data['comment'].apply(lambda x: ' '.join([word for word in str(x).split() if word.lower() not in stop_words_bangla]))

# %%
# Define text and label columns
text_column = 'comment'
target_column = 'tag'

# Split data into training and test sets
df_train, df_test = train_test_split(data, test_size=0.2, random_state=42)

# Tokenize text
max_sequence_length = 100  
max_features = 10000  
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(df_train[text_column])

# Convert text to sequences
X_train_text = tokenizer.texts_to_sequences(df_train[text_column])
X_test_text = tokenizer.texts_to_sequences(df_test[text_column])

# Apply padding
X_train_text = pad_sequences(X_train_text, maxlen=max_sequence_length, padding='post', truncating='post')
X_test_text = pad_sequences(X_test_text, maxlen=max_sequence_length, padding='post', truncating='post')

# Encode labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(df_train[target_column])
y_test = label_encoder.transform(df_test[target_column])

# %%
# Define the Bi-GRU model
model = models.Sequential([
    layers.Embedding(input_dim=max_features, output_dim=128, input_length=max_sequence_length),
    layers.Bidirectional(layers.GRU(128, return_sequences=True)),  # Bi-GRU Layer
    layers.GlobalMaxPooling1D(),
    layers.Dense(64, activation='relu'),
    layers.Dense(len(label_encoder.classes_), activation='softmax')  # Output layer
])

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
model.fit(X_train_text, y_train, epochs=100, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/100
# C:\Users\tonmo\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 24s 35ms/step - accuracy: 0.5346 - loss: 0.6897 - val_accuracy: 0.6018 - val_loss: 0.6706
# Epoch 2/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6471 - loss: 0.6340 - val_accuracy: 0.5906 - val_loss: 0.6936
# Epoch 3/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6895 - loss: 0.5811 - val_accuracy: 0.5809 - val_loss: 0.6980
# Epoch 4/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6994 - loss: 0.5533 - val_accuracy: 0.5911 - val_loss: 0.7277
# Epoch 5/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.7154 - loss: 0.5278 - val_accuracy: 0.5892 - val_loss: 0.7764
# Epoch 6/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.7089 - loss: 0.5210 - val_accuracy: 0.5906 - val_loss: 0.7986
# Epoch 7/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.7170 - loss: 0.5144 - val_accuracy: 0.5906 - val_loss: 0.8813
# Epoch 8/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - accuracy: 0.7187 - loss: 0.4992 - val_accuracy: 0.5879 - val_loss: 0.9726
# Epoch 9/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7267 - loss: 0.4855 - val_accuracy: 0.5902 - val_loss: 1.0298
# Epoch 10/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7240 - loss: 0.4875 - val_accuracy: 0.5948 - val_loss: 0.9963
# Epoch 11/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7266 - loss: 0.4775 - val_accuracy: 0.5925 - val_loss: 1.1424
# Epoch 12/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7382 - loss: 0.4712 - val_accuracy: 0.5920 - val_loss: 1.1914
# Epoch 13/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7359 - loss: 0.4672 - val_accuracy: 0.5925 - val_loss: 1.1438
# Epoch 14/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.7399 - loss: 0.4636 - val_accuracy: 0.5865 - val_loss: 1.4081
# Epoch 15/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7415 - loss: 0.4645 - val_accuracy: 0.5846 - val_loss: 1.2941
# Epoch 16/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.7429 - loss: 0.4610 - val_accuracy: 0.5906 - val_loss: 1.2852
# Epoch 17/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7405 - loss: 0.4593 - val_accuracy: 0.5828 - val_loss: 1.3225
# Epoch 18/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7434 - loss: 0.4532 - val_accuracy: 0.5772 - val_loss: 1.3500
# Epoch 19/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.
100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.7602 - loss: 0.4284 - val_accuracy: 0.5841 - val_loss: 2.0832
# Epoch 82/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - accuracy: 0.7528 - loss: 0.4333 - val_accuracy: 0.5846 - val_loss: 2.0382
# Epoch 83/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7592 - loss: 0.4298 - val_accuracy: 0.5814 - val_loss: 2.1302
# Epoch 84/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7634 - loss: 0.4253 - val_accuracy: 0.5809 - val_loss: 1.9577
# Epoch 85/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.7616 - loss: 0.4274 - val_accuracy: 0.5892 - val_loss: 1.9819
# Epoch 86/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.7581 - loss: 0.4267 - val_accuracy: 0.5814 - val_loss: 1.6817
# Epoch 87/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7656 - loss: 0.4289 - val_accuracy: 0.5832 - val_loss: 2.2317
# Epoch 88/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - accuracy: 0.7654 - loss: 0.4224 - val_accuracy: 0.5823 - val_loss: 2.0540
# Epoch 89/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 42s 69ms/step - accuracy: 0.7608 - loss: 0.4303 - val_accuracy: 0.5841 - val_loss: 2.2217
# Epoch 90/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 40s 66ms/step - accuracy: 0.7569 - loss: 0.4301 - val_accuracy: 0.5777 - val_loss: 2.2849
# Epoch 91/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7629 - loss: 0.4265 - val_accuracy: 0.5744 - val_loss: 2.1516
# Epoch 92/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7625 - loss: 0.4261 - val_accuracy: 0.5828 - val_loss: 2.3418
# Epoch 93/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7561 - loss: 0.4326 - val_accuracy: 0.5828 - val_loss: 1.6854
# Epoch 94/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7618 - loss: 0.4245 - val_accuracy: 0.5869 - val_loss: 1.8729
# Epoch 95/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7615 - loss: 0.4248 - val_accuracy: 0.5795 - val_loss: 2.0092
# Epoch 96/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7677 - loss: 0.4183 - val_accuracy: 0.5855 - val_loss: 2.0504
# Epoch 97/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 38ms/step - accuracy: 0.7596 - loss: 0.4310 - val_accuracy: 0.5865 - val_loss: 1.9339
# Epoch 98/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7602 - loss: 0.4226 - val_accuracy: 0.5828 - val_loss: 2.2510
# Epoch 99/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.7670 - loss: 0.4215 - val_accuracy: 0.5744 - val_loss: 2.2050
# Epoch 100/100
# 607/607 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - accuracy: 0.7595 - loss: 0.4259 - val_accuracy: 0.5846 - val_loss: 1.9684

# %%
# Predict on test data
test_preds = model.predict(X_test_text)
predicted_labels = test_preds.argmax(axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step

# %%
# Print classification report
print("Classification Report:\n", classification_report(y_test, predicted_labels, zero_division=0))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.58      0.58      2707
#            1       0.58      0.59      0.59      2686
#
#     accuracy                           0.58      5393
#    macro avg       0.58      0.58      0.58      5393
# weighted avg       0.58      0.58      0.58      5393

# %%
# Convert labels to one-hot encoding
n_classes = len(label_encoder.classes_)
y_bin = tf.one_hot(y_test, n_classes)

# Compute ROC curve
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], test_preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure()
colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve (area = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
# Compute Precision-Recall curve
plt.figure()
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_bin[:, i], test_preds[:, i])
    plt.plot(recall, precision, lw=2, label=f'Class {label_encoder.classes_[i]}')

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

# %%
# Compute weighted F1-score
from sklearn.metrics import precision_recall_fscore_support

f1_score_weighted = precision_recall_fscore_support(y_test, predicted_labels, average='weighted', zero_division=0)[2]
overall_score = (np.mean(list(roc_auc.values())) + f1_score_weighted) / 2

print(f"Overall Score: {overall_score:.2f}")
# Out:
# Overall Score: 0.60
