# %%
2
# Out:
# 2

# %%
import pandas as pd
import numpy as np
import requests
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import cycle

# %%
# Load dataset
data = pd.read_csv("Merged.csv")

# View sample data
print(data.head(20))
# Out:
#                                               comment       tag
# 0   আলহামদুলিল্লাহ সোনার বাংলার সোনার ছেলেরা দেশকে...  Positive
# 1                                            মাশাল্লা  Positive
# 2                                           এগিয়ে যাও  Positive
# 3                                             চমৎকার।  Positive
# 4   দেশের শিল্প পতিদের উচিত দেশিও প্রযুক্তি গুলোকে...   Neutral
# 5                                      আলহামদুলিল্লাহ  Positive
# 6   সোনার ছেলেরাও পারে।এদের পাশে শিল্পপতিরা দাড়ালে...  Positive
# 7   সব ঠিক আছে।   কিন্তু ফোল চার্জ হতে কত সময় লাগব...  Positive
# 8                                      আলহামদুলিল্লাহ  Positive
# 9   প্রয়জন আবিষ্কারের জনক। 'পালকি' তে সোলার রিলেডে...  Positive
# 10  দাম মধ্যবিত্তদের নাগালে রাখার অনুরোধ রইলো পালি...  Positive
# 11  আমি না শুধু মন চাইলে আপনারা ও কিনতে পারেন একলা...   Neutral
# 12  দেশের এসব তরুণ উদ্যোক্তাদের জন্য রইলো অনেক অনে...  Positive
# 13  ভাই তাড়াতাড়ি বানান আমাদের দরকার অনেক অনেক অন...  Positive
# 14  ৩ লক্ষ টাকার মধ্যে রাখতে হবে না হলে সুফল পাবে ...  Positive
# 15  বাংলাদেশে ইলেকট্রিক গাড়ির বড় একটি বাজার অলরে...  Positive
# 16      কত সুন্দর কথা "শুধু ভাত খেয়ে বেচে থাকতে পারি"  Positive
# 17    ভাই গাড়ির নাম টা এবং লোগো টা,  সুন্দর করা উচিত  Positive
# 18                                         মাশাআল্লাহ  Positive
# 19  ভাই চায়না অনেক বিদ্যুৎ চালিত গাড়ি আছে আপনার ...  Negative

# %%
# Check for missing values
print(data.isnull().sum())

# Drop missing values
data = data.dropna()
# Out:
# comment    0
# tag        5
# dtype: int64

# %%
# Correct common label typos
label_corrections = {
    "Neutural": "Neutral",
    "Meutral": "Neutral",
    "N EUTRAL": "Neutral",
    "NEUTRANEG": "Neutral",
    "Negetive": "Negative",
    "NEGNEG": "Negative",
    "Negativee": "Negative",
    "NEG": "Negative"
}

data['tag'] = data['tag'].replace(label_corrections)

# Remove the 'Neutral' class
data = data[data['tag'] != 'Neutral']

# %%
# Identify unique labels
print("Unique labels in dataset:", data['tag'].unique())

# Assume the first label is the positive class
positive_class_label = data['tag'].unique()[0]
positive_class = data[data['tag'] == positive_class_label]

# Reduce the count of the positive class
if len(positive_class) >= 10780:
    rows_to_remove = positive_class.sample(n=10780, random_state=42)
    data = data.drop(rows_to_remove.index)
else:
    print(f"Less than 10,000 positive rows available (found {len(positive_class)}).")
# Out:
# Unique labels in dataset: ['Positive' 'Negative']

# %%
# Load Bangla stopwords
stopwords_url = "https://raw.githubusercontent.com/stopwords-iso/stopwords-bn/master/stopwords-bn.txt"
response = requests.get(stopwords_url)

if response.status_code == 200:
    stop_words_bangla = set(response.text.splitlines())
    
    # Remove stopwords
    data['comment'] = data['comment'].apply(lambda x: ' '.join([word for word in str(x).split() if word.lower() not in stop_words_bangla]))

# %%
# Define text and label columns
text_column = 'comment'
target_column = 'tag'

# Split data into training and test sets
df_train, df_test = train_test_split(data, test_size=0.2, random_state=42)

# Tokenize text
max_sequence_length = 100  
max_features = 10000  
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(df_train[text_column])

# Convert text to sequences
X_train_text = tokenizer.texts_to_sequences(df_train[text_column])
X_test_text = tokenizer.texts_to_sequences(df_test[text_column])

# Apply padding
X_train_text = pad_sequences(X_train_text, maxlen=max_sequence_length, padding='post', truncating='post')
X_test_text = pad_sequences(X_test_text, maxlen=max_sequence_length, padding='post', truncating='post')

# Encode labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(df_train[target_column])
y_test = label_encoder.transform(df_test[target_column])

# %%
# Define the ANN model
model = Sequential([
    Embedding(input_dim=max_features, output_dim=128, input_length=max_sequence_length),
    Flatten(),  # Flatten for ANN
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')  # Output layer
])

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train model
model.fit(X_train_text, y_train, epochs=100, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/100
# C:\Users\tonmo\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.5198 - loss: 0.7019 - val_accuracy: 0.5463 - val_loss: 0.6900
# Epoch 2/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5413 - loss: 0.6907 - val_accuracy: 0.5463 - val_loss: 0.6897
# Epoch 3/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5377 - loss: 0.6905 - val_accuracy: 0.5463 - val_loss: 0.6897
# Epoch 4/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5494 - loss: 0.6886 - val_accuracy: 0.5478 - val_loss: 0.6888
# Epoch 5/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5386 - loss: 0.6900 - val_accuracy: 0.5463 - val_loss: 0.6896
# Epoch 6/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5388 - loss: 0.6900 - val_accuracy: 0.5463 - val_loss: 0.6920
# Epoch 7/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5338 - loss: 0.6893 - val_accuracy: 0.5468 - val_loss: 0.6935
# Epoch 8/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5442 - loss: 0.6882 - val_accuracy: 0.5468 - val_loss: 0.6884
# Epoch 9/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5457 - loss: 0.6890 - val_accuracy: 0.5463 - val_loss: 0.6942
# Epoch 10/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5449 - loss: 0.6887 - val_accuracy: 0.5463 - val_loss: 0.6931
# Epoch 11/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5415 - loss: 0.6894 - val_accuracy: 0.5463 - val_loss: 0.6948
# Epoch 12/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5433 - loss: 0.6883 - val_accuracy: 0.5463 - val_loss: 0.6918
# Epoch 13/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5450 - loss: 0.6884 - val_accuracy: 0.5463 - val_loss: 0.6950
# Epoch 14/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5411 - loss: 0.6890 - val_accuracy: 0.5463 - val_loss: 0.7016
# Epoch 15/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5374 - loss: 0.6898 - val_accuracy: 0.5463 - val_loss: 0.7077
# Epoch 16/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5401 - loss: 0.6891 - val_accuracy: 0.5463 - val_loss: 0.7308
# Epoch 17/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.5421 - loss: 0.6852 - val_accuracy: 0.5463 - val_loss: 0.7232
# Epoch 18/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.
100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7511 - loss: 0.4797 - val_accuracy: 0.5789 - val_loss: 2.2248
# Epoch 79/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7518 - loss: 0.4779 - val_accuracy: 0.5779 - val_loss: 1.7704
# Epoch 80/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7549 - loss: 0.4761 - val_accuracy: 0.5794 - val_loss: 2.2276
# Epoch 81/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7475 - loss: 0.4768 - val_accuracy: 0.5799 - val_loss: 1.9179
# Epoch 82/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7479 - loss: 0.4744 - val_accuracy: 0.5769 - val_loss: 2.0097
# Epoch 83/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7518 - loss: 0.4719 - val_accuracy: 0.5759 - val_loss: 2.0596
# Epoch 84/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7512 - loss: 0.4757 - val_accuracy: 0.5804 - val_loss: 2.0031
# Epoch 85/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7547 - loss: 0.4724 - val_accuracy: 0.5779 - val_loss: 2.2796
# Epoch 86/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7499 - loss: 0.4710 - val_accuracy: 0.5789 - val_loss: 2.0784
# Epoch 87/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7517 - loss: 0.4701 - val_accuracy: 0.5789 - val_loss: 2.0097
# Epoch 88/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7463 - loss: 0.4704 - val_accuracy: 0.5774 - val_loss: 2.3673
# Epoch 89/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7500 - loss: 0.4694 - val_accuracy: 0.5729 - val_loss: 2.2580
# Epoch 90/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7518 - loss: 0.4736 - val_accuracy: 0.5729 - val_loss: 1.8737
# Epoch 91/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7475 - loss: 0.4731 - val_accuracy: 0.5739 - val_loss: 2.4129
# Epoch 92/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7523 - loss: 0.4696 - val_accuracy: 0.5774 - val_loss: 2.3399
# Epoch 93/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7502 - loss: 0.4676 - val_accuracy: 0.5804 - val_loss: 2.6694
# Epoch 94/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7545 - loss: 0.4650 - val_accuracy: 0.5834 - val_loss: 2.6407
# Epoch 95/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7482 - loss: 0.4702 - val_accuracy: 0.5819 - val_loss: 2.3360
# Epoch 96/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7501 - loss: 0.4679 - val_accuracy: 0.5804 - val_loss: 2.6579
# Epoch 97/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7493 - loss: 0.4690 - val_accuracy: 0.5814 - val_loss: 2.5630
# Epoch 98/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7553 - loss: 0.4616 - val_accuracy: 0.5829 - val_loss: 2.6015
# Epoch 99/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7521 - loss: 0.4631 - val_accuracy: 0.5799 - val_loss: 1.8134
# Epoch 100/100
# 562/562 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7556 - loss: 0.4633 - val_accuracy: 0.5804 - val_loss: 2.3761

# %%
# Predict on test data
test_preds = model.predict(X_test_text)
predicted_labels = test_preds.argmax(axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Print classification report
print("Classification Report:\n", classification_report(y_test, predicted_labels, zero_division=0))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60      2661
#            1       0.54      0.54      0.54      2332
#
#     accuracy                           0.57      4993
#    macro avg       0.57      0.57      0.57      4993
# weighted avg       0.57      0.57      0.57      4993

# %%
# Convert labels to one-hot encoding
n_classes = len(label_encoder.classes_)
y_bin = tf.one_hot(y_test, n_classes)

# Compute ROC curve
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_bin[:, i], test_preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure()
colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve (area = {roc_auc[i]:0.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
# Compute Precision-Recall curve
plt.figure()
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(y_bin[:, i], test_preds[:, i])
    plt.plot(recall, precision, lw=2, label=f'Class {label_encoder.classes_[i]}')

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()
